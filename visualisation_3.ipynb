# %% [markdown]
# # Visualisation 3
#
# Today we will learn about image display, subplots and heatmaps.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exercise 1: Image Display
#
# We'll import a couple of libraries to let us open an image from the internet:

# %%
from PIL import Image
import requests

# %%
url = 'https://worldanimalfoundation.org/wp-content/uploads/2022/10/About-the-Breed-review-2.jpg'
im = np.array(Image.open(requests.get(url, stream=True).raw), dtype=int)

# %% [markdown]
# The image is an array in `im`.  Display the image using matplotlib's `imshow` method: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html

# %%
plt.imshow(im)

# %% [markdown]
# Now select just the region corresponding to the head and display it in a separate plot.  Remember the image is just an array, use array indexing!  `my_subarray = my_array[i:j,k:l]`

# %%
im_head = im[25:200,250:425]
plt.imshow(im_head)

# %% [markdown]
# ### Exercise 2: Subplots
#
# Instead of just showing one plot in a figure in matplotlib, it is possible to display multiple plots/images in the same figure.  Let's make a figure with four equal subplots arranged in a square:

# %%
plt.subplots(2,2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<AxesSubplot: >, <AxesSubplot: >],
#         [<AxesSubplot: >, <AxesSubplot: >]], dtype=object))

# %% [markdown]
# I can choose to plot something in one of the panels.  Let's say I want to display the original image `im` in the bottom left panel:

# %%
plt.subplots(2,2)
plt.subplot(2,2,3)
plt.imshow(im)

# %% [markdown]
# Now I would like you to move the image to the top right subplot, how will you do this?  Look at the documentation here: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html

# %%
plt.subplots(2,2)
plt.subplot(2,2,2)
plt.imshow(im)

# %% [markdown]
# Now I would like you to make a similar array of four plots in one figure with the full image top left, just the head top right, just the tail bottom left and just some grass bottom right.

# %%
plt.subplots(2,2 )
# full image in top left
plt.subplot(2, 2, 1)
plt.imshow(im)
# head in top right
plt.subplot(2, 2, 2)
plt.imshow(im_head)
# define the tail image and plot
im_tail = im[50:200, 550:675]
plt.subplot(2, 2, 3)
plt.imshow(im_tail)
# define the grass image and plot
im_grass = im[200:400, 50:200]
plt.subplot(2, 2, 4)
plt.imshow(im_grass)

# %% [markdown]
# ### Exercise 3: Heatmaps
#
# Now we will look at heatmaps.  You are given the following data (both lengths, in cm), `gaus2d`:

# %%
mus = [1.0,1.0]
sigmas = [[0.1,0.0,],[0.0,1.0]]
npoints = 10000
gaus2d = np.random.multivariate_normal(mus, sigmas, npoints)

# %% [markdown]
# Make a two dimensional histogram (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist2d.html) showing the first column against the second column.  Also include a colorbar (https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.colorbar.html).

# %%
plt.hist2d(gaus2d[:, 0], gaus2d[:, 1], bins=25)
plt.colorbar(location='left')
plt.show()

# %% [markdown]
# Label your axes including units.  Take a look at the available colour schemes: https://matplotlib.org/stable/users/explain/colors/colormaps.html.  Choose a different colour map from the choices of sequential colour maps and replot your data.  It is a good idea to use sequential colour maps as these should still work in black and white.  Also change your binning so the bin edges are not at the peak of the distribution (the easiest way to do this is just to use odd numbers).

# %%
plt.hist2d(gaus2d[:, 0], gaus2d[:, 1], bins=15, cmap='cool')
plt.colorbar(location='top')
plt.xlabel('Length (cms)')
plt.ylabel('Length (cms)')
plt.show()

# %% [markdown]
# ### Exercise 4: Heatmaps
#
# Remember to include axis labels, units, a colorbar and a sensible choice of colours/shades.  We will be using the `pydataset` module which contains many datasets.  The next line may take a little while to run the first time only but please DO NOT INTERRUPT IT!

# %%
from pydataset import data
# Out:
# initiated datasets repo at: /Users/kavittolia/.pydataset/

# %% [markdown]
# We will be looking at the `iris` dataset, specifically at the petal lengths and widths.

# %%
df = data('iris')
petal_length = np.array(df['Petal.Length'])
petal_width = np.array(df['Petal.Width'])

# %% [markdown]
# Make a two-dimensional histogram of these data.  Remember to include axis labels, units, a colorbar and a sensible choice of colours/shades.  Choose a sensible binning.  Save your figure as a pdf.

# %%
plt.hist2d(petal_length, petal_width, bins=15, cmap='cool')
plt.colorbar(location='top')
plt.xlabel('Length (cms)')
plt.ylabel('Length (cms)')
plt.show()
